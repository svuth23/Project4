# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexFeeney/Project4_Group3/blob/main/Kmeans_Prac_Himali_VyEdit_240319.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a working environment

# !sudo apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Check this site for the latest download link https://www.apache.org/dyn/closer.lua/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !wget -q https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !tar xf spark-3.2.1-bin-hadoop3.2.tgz
# !pip install -q findspark
# !pip install pyspark
# !pip install py4j
# !pip install hvplot
import os
import sys
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,570 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [770 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,080 kB]
# ...

# %%
# Import packages

import findspark
findspark.init()
findspark.find()
import pyspark
from pyspark.sql import DataFrame, SparkSession
import time
from typing import List
import pyspark.sql.types as T
import pyspark.sql.functions as F
import pandas as pd
import numpy as np
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Create a SparkSession

spark= SparkSession \
       .builder \
       .appName("Project 4 Group 3 Spark") \
       .getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://465d3304ff4f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Project 4 Group 3 Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Read in data

# %%
# Read in data from Github as a DataFrame.
from pyspark import SparkFiles
url = "https://raw.githubusercontent.com/AlexFeeney/Project4_Group3/main/Data/healthcare-dataset-stroke-data.csv"
spark.sparkContext.addFile(url)
df = spark.read.csv(SparkFiles.get("healthcare-dataset-stroke-data.csv"), sep=",", header=True)

# Show DataFrame
df.show()
# Out:
# +-----+------+---+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# |   id|gender|age|hypertension|heart_disease|ever_married|    work_type|Residence_type|avg_glucose_level| bmi| smoking_status|stroke|
# +-----+------+---+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# | 9046|  Male| 67|           0|            1|         Yes|      Private|         Urban|           228.69|36.6|formerly smoked|     1|
# |51676|Female| 61|           0|            0|         Yes|Self-employed|         Rural|           202.21| N/A|   never smoked|     1|
# |31112|  Male| 80|           0|            1|         Yes|      Private|         Rural|           105.92|32.5|   never smoked|     1|
# |60182|Female| 49|           0|            0|         Yes|      Private|         Urban|           171.23|34.4|         smokes|     1|
# ...

# %% [markdown]
# # Preprocessing data

# %%
# Convert DataFrame to Pandas DataFrame
pandas_df = df.toPandas()

# %%
# Determine the number of unique values in each column.
pandas_df.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   419
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
# Count unique values in column 'gender'
pandas_df['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
# Conditionally drop rows where column 'gender' contains the text 'Other'
pandas_df_clean = pandas_df[~pandas_df['gender'].str.contains('Other')]

pandas_df_clean['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Name: gender, dtype: int64

# %%
# Conditionally drop rows where column 'bmi' contains the text 'N/A'
pandas_df_clean = pandas_df_clean[~pandas_df_clean['bmi'].str.contains('N/A')]

pandas_df_clean['gender'].value_counts()
# Out:
# Female    2897
# Male      2011
# Name: gender, dtype: int64

# %%
# Drop the non-beneficial 'id' columns
pandas_df_clean = pandas_df_clean.drop(columns = ['id'])
pandas_df_clean.head()
# Out:
#    gender age hypertension heart_disease ever_married      work_type  \
# 0    Male  67            0             1          Yes        Private
# 2    Male  80            0             1          Yes        Private
# 3  Female  49            0             0          Yes        Private
# 4  Female  79            1             0          Yes  Self-employed
# 5    Male  81            0             0          Yes        Private
#
#   Residence_type avg_glucose_level   bmi   smoking_status stroke
# 0          Urban            228.69  36.6  formerly smoked      1
# 2          Rural            105.92  32.5     never smoked      1
# 3          Urban            171.23  34.4           smokes      1
# 4          Rural            174.12    24     never smoked      1
# 5          Urban            186.21    29  formerly smoked      1

# %%
# Check data types of columns
print(pandas_df_clean.dtypes)
# Out:
# gender               object
# age                  object
# hypertension         object
# heart_disease        object
# ever_married         object
# work_type            object
# Residence_type       object
# avg_glucose_level    object
# bmi                  object
# smoking_status       object
# stroke               object
# dtype: object

# %%
# Create dummy data for the categorical features
categorical_cols = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

pandas_df_clean_numeric = pd.get_dummies(pandas_df_clean, columns=categorical_cols, dtype=int)

pandas_df_clean_numeric
# Out:
#      age hypertension heart_disease avg_glucose_level   bmi stroke  \
# 0     67            0             1            228.69  36.6      1
# 2     80            0             1            105.92  32.5      1
# 3     49            0             0            171.23  34.4      1
# 4     79            1             0            174.12    24      1
# 5     81            0             0            186.21    29      1
# ...   ..          ...           ...               ...   ...    ...
# 5104  13            0             0            103.08  18.6      0
# 5106  81            0             0             125.2    40      0
# 5107  35            0             0             82.99  30.6      0
# 5108  51            0             0            166.29  25.6      0
# 5109  44            0             0             85.28  26.2      0
#
#       gender_Female  gender_Male  ever_married_No  ever_married_Yes  ...  \
# 0                 0            1                0                 1  ...
# ...

# %% [markdown]
# # Normalizing data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
pandas_df_clean_numeric_scaled = StandardScaler().fit_transform(
    pandas_df_clean_numeric[["age","avg_glucose_level","bmi"]]
)

# Review the data
pandas_df_clean_numeric_scaled
# Out:
# array([[ 1.06993757,  2.77779723,  0.98114481],
#        [ 1.64633634,  0.01401584,  0.45908589],
#        [ 0.27184695,  1.48426559,  0.70101563],
#        ...,
#        [-0.34889019, -0.50218118,  0.21715615],
#        [ 0.36052369,  1.37305699, -0.41950107],
#        [ 0.05015511, -0.45062901, -0.3431022 ]])

# %%
# Create a DataFrame of the scaled data
pandas_df_clean_numeric_scaled = pd.DataFrame(pandas_df_clean_numeric_scaled, columns=["age","avg_glucose_level","bmi"])

# Replace the original data with the columns of information from the scaled Data
pandas_df_clean_numeric["age"] = pandas_df_clean_numeric_scaled["age"]
pandas_df_clean_numeric["avg_glucose_level"] = pandas_df_clean_numeric_scaled["avg_glucose_level"]
pandas_df_clean_numeric["bmi"] = pandas_df_clean_numeric_scaled["bmi"]

# Review the DataFrame
pandas_df_clean_numeric
# Out:
#            age hypertension heart_disease  avg_glucose_level       bmi stroke  \
# 0     1.069938            0             1           2.777797  0.981145      1
# 2     0.271847            0             1           1.484266  0.701016      1
# 3     1.601998            0             0           1.549325 -0.623231      1
# 4     1.690675            1             0           1.821493  0.013426      1
# 5     1.380306            0             0          -0.792584 -0.190304      1
# ...        ...          ...           ...                ...       ...    ...
# 5104       NaN            0             0                NaN       NaN      0
# 5106       NaN            0             0                NaN       NaN      0
# 5107       NaN            0             0                NaN       NaN      0
# 5108       NaN            0             0                NaN       NaN      0
# 5109       NaN            0             0                NaN       NaN      0
#
# ...

# %%
# Remove the "NaN" containing rows
pandas_df_clean_numeric = pandas_df_clean_numeric.dropna()
pandas_df_clean_numeric
# Out:
#            age hypertension heart_disease  avg_glucose_level       bmi stroke  \
# 0     1.069938            0             1           2.777797  0.981145      1
# 2     0.271847            0             1           1.484266  0.701016      1
# 3     1.601998            0             0           1.549325 -0.623231      1
# 4     1.690675            1             0           1.821493  0.013426      1
# 5     1.380306            0             0          -0.792584 -0.190304      1
# ...        ...          ...           ...                ...       ...    ...
# 4903 -1.324334            0             0          -0.049918 -1.310821      0
# 4904  1.690675            0             0           0.448045  1.414072      0
# 4905 -0.348890            0             0          -0.502181  0.217156      0
# 4906  0.360524            0             0           1.373057 -0.419501      0
# 4907  0.050155            0             0          -0.450629 -0.343102      0
#
# ...

# %%
# Remove the "stroke" column
pandas_df_clean_numeric_nolabel = pandas_df_clean_numeric.drop("stroke", axis=1)
pandas_df_clean_numeric_nolabel
# Out:
#            age hypertension heart_disease  avg_glucose_level       bmi  \
# 0     1.069938            0             1           2.777797  0.981145
# 2     0.271847            0             1           1.484266  0.701016
# 3     1.601998            0             0           1.549325 -0.623231
# 4     1.690675            1             0           1.821493  0.013426
# 5     1.380306            0             0          -0.792584 -0.190304
# ...        ...          ...           ...                ...       ...
# 4903 -1.324334            0             0          -0.049918 -1.310821
# 4904  1.690675            0             0           0.448045  1.414072
# 4905 -0.348890            0             0          -0.502181  0.217156
# 4906  0.360524            0             0           1.373057 -0.419501
# 4907  0.050155            0             0          -0.450629 -0.343102
#
#       gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# ...

# %% [markdown]
# # Find the Best Value for k Using the Original Data

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_stocks_scaled`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    k_model = KMeans(n_clusters=i, random_state=0)
    k_model.fit(pandas_df_clean_numeric_nolabel)
    inertia.append(k_model.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
#    k       inertia
# 0  1  27705.937655
# 1  2  23143.698571
# 2  3  19904.792581
# 3  4  18387.842473
# 4  5  17177.589818

# %%
import holoviews as hv
hv.extension('bokeh')

# Plot the Elbow curve
df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Curve   [k]   (inertia)

# %% [markdown]
# # Cluster "stroke" with K-means Using the pandas_df_clean_numeric_nolabel data

# %%
# Initialise the K-Means model using the best value for k
model = KMeans(n_clusters=2, random_state=0)

# %%
# Fit the K-Means model using the scaled data
model.fit(pandas_df_clean_numeric_nolabel)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=0)

# %%
# Predict the clusters to group the data using the pandas_df_clean_numeric_nolabel
k_2 = model.predict(pandas_df_clean_numeric_nolabel)

# Print the resulting array of cluster values.
print(k_2)
# Out:
# [1 1 1 ... 0 1 0]

# %%
# Create a copy of the DataFrame
pandas_df_clean_numeric_withprediction = pandas_df_clean_numeric.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
pandas_df_clean_numeric_withprediction["predicted_cluster"] = k_2

# Display sample data
pandas_df_clean_numeric_withprediction
# Out:
#            age hypertension heart_disease  avg_glucose_level       bmi stroke  \
# 0     1.069938            0             1           2.777797  0.981145      1
# 2     0.271847            0             1           1.484266  0.701016      1
# 3     1.601998            0             0           1.549325 -0.623231      1
# 4     1.690675            1             0           1.821493  0.013426      1
# 5     1.380306            0             0          -0.792584 -0.190304      1
# ...        ...          ...           ...                ...       ...    ...
# 4903 -1.324334            0             0          -0.049918 -1.310821      0
# 4904  1.690675            0             0           0.448045  1.414072      0
# 4905 -0.348890            0             0          -0.502181  0.217156      0
# 4906  0.360524            0             0           1.373057 -0.419501      0
# 4907  0.050155            0             0          -0.450629 -0.343102      0
#
# ...

# %%
import holoviews as hv
hv.extension('bokeh')

# Create a scatter plot using hvPlot by setting
# `x="avg_glucose_level"` and `y="bmi"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_predicted_plot1 = pandas_df_clean_numeric_withprediction.hvplot.scatter(
    x="avg_glucose_level",
    y="bmi",
    by="predicted_cluster",
    hover_cols="stroke"
)

cluster_predicted_plot1
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :NdOverlay   [predicted_cluster]
#    :Scatter   [avg_glucose_level]   (bmi,stroke)

# %%
import holoviews as hv
hv.extension('bokeh')

# Create a scatter plot using hvPlot by setting
# `x="avg_glucose_level"` and `y="bmi"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_original_plot1 = pandas_df_clean_numeric_withprediction.hvplot.scatter(
    x="avg_glucose_level",
    y="bmi",
    by="stroke",
    hover_cols="stroke"
)

cluster_original_plot1
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :NdOverlay   [stroke]
#    :Scatter   [avg_glucose_level]   (bmi,stroke)

# %%
import holoviews as hv
hv.extension('bokeh')

# Create a scatter plot using hvPlot by setting
# `x="avg_glucose_level"` and `y="age"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_predicted_plot2 = pandas_df_clean_numeric_withprediction.hvplot.scatter(
    x="avg_glucose_level",
    y="age",
    by="predicted_cluster",
    hover_cols="stroke"
)

cluster_predicted_plot2
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :NdOverlay   [predicted_cluster]
#    :Scatter   [avg_glucose_level]   (age,stroke)

# %%
import holoviews as hv
hv.extension('bokeh')

# Create a scatter plot using hvPlot by setting
# `x="avg_glucose_level"` and `y="age"`.
# Colour the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
cluster_original_plot2 = pandas_df_clean_numeric_withprediction.hvplot.scatter(
    x="avg_glucose_level",
    y="age",
    by="stroke",
    hover_cols="stroke"
)

cluster_original_plot2
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :NdOverlay   [stroke]
#    :Scatter   [avg_glucose_level]   (age,stroke)
